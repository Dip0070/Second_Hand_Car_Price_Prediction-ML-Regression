# %% [markdown]
# ## Step 1- Reading Data into Python

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
carpricesdata = pd.read_csv("CarPricesData.csv",sep= ',',encoding = 'latin-1')

# %%
carpricesdata
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic      CC  Doors  \
# 0     13500  23.0  46986   Diesel   90         1          0  2000.0      3
# 1     13750  23.0  72937   Diesel   90         1          0  2000.0      3
# 2     13950  24.0  41711   Diesel   90         1          0  2000.0      3
# 3     14950  26.0  48000   Diesel   90         0          0  2000.0      3
# 4     13750  30.0  38500   Diesel   90         0          0  2000.0      3
# ...     ...   ...    ...      ...  ...       ...        ...     ...    ...
# 1431   7500  69.0  20544   Petrol   86         1          0  1300.0      3
# 1432  10845  72.0  19000   Petrol   86         0          0  1300.0      3
# 1433   8500  71.0  17016   Petrol   86         0          0  1300.0      3
# 1434   7250  70.0  16916   Petrol   86         1          0  1300.0      3
# 1435   6950  76.0      1   Petrol  110         0          0  1600.0      5
#
#       Weight
# 0     1165.0
# 1     1165.0
# 2     1165.0
# 3     1165.0
# 4     1170.0
# ...      ...
# 1431  1025.0
# 1432  1015.0
# 1433  1015.0
# 1434  1015.0
# 1435  1114.0
#
# [1436 rows x 10 columns]

# %% [markdown]
# ## Step 2- Defining the Problem Statement

# %%
print(type(carpricesdata))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
pd.options.display.max_columns = 10
pd.options.display.max_rows = 100
carpricesdata
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic      CC  Doors  \
# 0     13500  23.0  46986   Diesel   90         1          0  2000.0      3
# 1     13750  23.0  72937   Diesel   90         1          0  2000.0      3
# 2     13950  24.0  41711   Diesel   90         1          0  2000.0      3
# 3     14950  26.0  48000   Diesel   90         0          0  2000.0      3
# 4     13750  30.0  38500   Diesel   90         0          0  2000.0      3
# ...     ...   ...    ...      ...  ...       ...        ...     ...    ...
# 1431   7500  69.0  20544   Petrol   86         1          0  1300.0      3
# 1432  10845  72.0  19000   Petrol   86         0          0  1300.0      3
# 1433   8500  71.0  17016   Petrol   86         0          0  1300.0      3
# 1434   7250  70.0  16916   Petrol   86         1          0  1300.0      3
# 1435   6950  76.0      1   Petrol  110         0          0  1600.0      5
#
#       Weight
# 0     1165.0
# 1     1165.0
# 2     1165.0
# 3     1165.0
# 4     1170.0
# ...      ...
# 1431  1025.0
# 1432  1015.0
# 1433  1015.0
# 1434  1015.0
# 1435  1114.0
#
# [1436 rows x 10 columns]

# %% [markdown]
# ## Step 3- Defining Type of Machine Learning

# %%
print('Shape before deleting duplicates', carpricesdata.shape)
carpricesdata = carpricesdata.drop_duplicates()
print('Shape after deleting duplicates', carpricesdata.shape)
# Out:
# Shape before deleting duplicates (1436, 10)
# Shape after deleting duplicates (1435, 10)

# %% [markdown]
# ## Step 4 - Looking the Distribution of Target Variable

# %%
carpricesdata.head(5)
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic      CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90         1          0  2000.0      3  1165.0
# 1  13750  23.0  72937   Diesel  90         1          0  2000.0      3  1165.0
# 2  13950  24.0  41711   Diesel  90         1          0  2000.0      3  1165.0
# 3  14950  26.0  48000   Diesel  90         0          0  2000.0      3  1165.0
# 4  13750  30.0  38500   Diesel  90         0          0  2000.0      3  1170.0

# %%
carpricesdata.tail(5)
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic      CC  Doors  \
# 1431   7500  69.0  20544   Petrol   86         1          0  1300.0      3
# 1432  10845  72.0  19000   Petrol   86         0          0  1300.0      3
# 1433   8500  71.0  17016   Petrol   86         0          0  1300.0      3
# 1434   7250  70.0  16916   Petrol   86         1          0  1300.0      3
# 1435   6950  76.0      1   Petrol  110         0          0  1600.0      5
#
#       Weight
# 1431  1025.0
# 1432  1015.0
# 1433  1015.0
# 1434  1015.0
# 1435  1114.0

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Project Machine Learning\\Car Price Data Analysis'

# %% [markdown]
# ## Step 5- Basic Data Exploration

# %%
carpricesdata.nunique()
# Out:
# Price         236
# Age            77
# KM           1263
# FuelType        3
# HP             12
# MetColor        2
# Automatic       2
# CC             12
# Doors           4
# Weight         59
# dtype: int64

# %%
carpricesdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1435 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1435 non-null   int64
#  1   Age        1433 non-null   float64
#  2   KM         1435 non-null   int64
#  3   FuelType   1431 non-null   object
#  4   HP         1435 non-null   int64
#  5   MetColor   1435 non-null   int64
#  6   Automatic  1435 non-null   int64
#  7   CC         1433 non-null   float64
#  8   Doors      1435 non-null   int64
#  9   Weight     1433 non-null   float64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 123.3+ KB

# %%
carpricesdata.describe()
# Out:
#               Price          Age             KM           HP     MetColor  \
# count   1435.000000  1433.000000    1435.000000  1435.000000  1435.000000
# mean   10720.915679    56.020237   68571.782578   101.491986     0.674564
# std     3608.732978    18.544948   37491.094553    14.981408     0.468701
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000     1.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#          Automatic           CC        Doors       Weight
# count  1435.000000  1433.000000  1435.000000  1433.000000
# mean      0.055749  1566.688765     4.032753  1072.314724
# std       0.229517   186.893360     0.952667    52.283038
# min       0.000000  1300.000000     2.000000  1000.000000
# 25%       0.000000  1400.000000     3.000000  1040.000000
# 50%       0.000000  1600.000000     4.000000  1070.000000
# 75%       0.000000  1600.000000     5.000000  1085.000000
# max       1.000000  2000.000000     5.000000  1615.000000

# %%
carpricesdata.describe(include = 'all')
# Out:
#                Price          Age             KM FuelType           HP  \
# count    1435.000000  1433.000000    1435.000000     1431  1435.000000
# unique           NaN          NaN            NaN        3          NaN
# top              NaN          NaN            NaN   Petrol          NaN
# freq             NaN          NaN            NaN     1260          NaN
# mean    10720.915679    56.020237   68571.782578      NaN   101.491986
# std      3608.732978    18.544948   37491.094553      NaN    14.981408
# min      4350.000000     1.000000       1.000000      NaN    69.000000
# 25%      8450.000000    44.000000   43000.000000      NaN    90.000000
# 50%      9900.000000    61.000000   63451.000000      NaN   110.000000
# 75%     11950.000000    70.000000   87041.500000      NaN   110.000000
# max     32500.000000    80.000000  243000.000000      NaN   192.000000
#
#            MetColor    Automatic           CC        Doors       Weight
# count   1435.000000  1435.000000  1433.000000  1435.000000  1433.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       0.674564     0.055749  1566.688765     4.032753  1072.314724
# std        0.468701     0.229517   186.893360     0.952667    52.283038
# min        0.000000     0.000000  1300.000000     2.000000  1000.000000
# 25%        0.000000     0.000000  1400.000000     3.000000  1040.000000
# 50%        1.000000     0.000000  1600.000000     4.000000  1070.000000
# 75%        1.000000     0.000000  1600.000000     5.000000  1085.000000
# max        1.000000     1.000000  2000.000000     5.000000  1615.000000

# %%
carpricesdata['MetColor'].mode()
# Out:
# 0    1
# Name: MetColor, dtype: int64

# %%
carpricesdata['Price'].min()
# Out:
# 4350

# %%
carpricesdata['Price'].max()
# Out:
# 32500

# %%
carpricesdata['Price'].mean()
# Out:
# 10720.915679442509

# %%
np.std(carpricesdata['Price'])
# Out:
# 3607.475360775768

# %%
np.var(carpricesdata['Price'])
# Out:
# 13013878.478604257

# %%
carpricesdata.shape
# Out:
# (1435, 10)

# %%
carpricesdata.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
carpricesdata.values
# Out:
# array([[13500, 23.0, 46986, ..., 2000.0, 3, 1165.0],
#        [13750, 23.0, 72937, ..., 2000.0, 3, 1165.0],
#        [13950, 24.0, 41711, ..., 2000.0, 3, 1165.0],
#        ...,
#        [8500, 71.0, 17016, ..., 1300.0, 3, 1015.0],
#        [7250, 70.0, 16916, ..., 1300.0, 3, 1015.0],
#        [6950, 76.0, 1, ..., 1600.0, 5, 1114.0]], dtype=object)

# %%
carpricesdata.iloc[0:5]
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic      CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90         1          0  2000.0      3  1165.0
# 1  13750  23.0  72937   Diesel  90         1          0  2000.0      3  1165.0
# 2  13950  24.0  41711   Diesel  90         1          0  2000.0      3  1165.0
# 3  14950  26.0  48000   Diesel  90         0          0  2000.0      3  1165.0
# 4  13750  30.0  38500   Diesel  90         0          0  2000.0      3  1170.0

# %%
subset = carpricesdata.iloc[[1,5,8,6,7],[0,5,4,2]]
subset = subset.reset_index(drop = True)
subset
# Out:
#    Price  MetColor   HP     KM
# 0  13750         1   90  72937
# 1  12950         0   90  61000
# 2  21500         0  192  19700
# 3  16900         1   90  94612
# 4  18600         1   90  75889

# %% [markdown]
# ## Step 6- Visual Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
carpricesdata.hist()
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Age'}>, <Axes: title={'center': 'KM'}>],
#        [<Axes: title={'center': 'HP'}>,
#         <Axes: title={'center': 'MetColor'}>,
#         <Axes: title={'center': 'Automatic'}>],
#        [<Axes: title={'center': 'CC'}>,
#         <Axes: title={'center': 'Doors'}>,
#         <Axes: title={'center': 'Weight'}>]], dtype=object)

# %%
carpricesdata['Price'].hist(figsize = (15,5),color ='steelblue',bins =20)
# Out:
# <Axes: >

# %%
carpricesdata.groupby(['FuelType']).size()
# Out:
# FuelType
# CNG         17
# Diesel     154
# Petrol    1260
# dtype: int64

# %%
gd = carpricesdata.groupby(['Automatic'])

# %%
# gd.sum()
# gd.count()
gd.size()
# Out:
# Automatic
# 0    1355
# 1      80
# dtype: int64

# %%
# gd.size().plot(kind='pie')
# gd.size().plot(kind='bar')
# gd.size().plot(kind='line')
gd.size().plot(kind='barh', color = 'red', figsize=(10,5))
# Out:
# <Axes: ylabel='Automatic'>

# %%
# %matplotlib inline
carpricesdata.plot.scatter(x = 'Age', y= 'Price', figsize = (10,5), marker = "*", color = 'blue')
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
import matplotlib.pyplot as plt

fig, subplot = plt.subplots(nrows= 2, ncols = 3, figsize=(18,8))
fig.suptitle('Price vs AGE, KM and Weight')
carpricesdata.plot.scatter(x = 'Age', y = "Price", color = "blue", ax = subplot[1,0])
carpricesdata.plot.scatter(x = 'KM', y = "Price", color = "blue", ax = subplot[0,1])
carpricesdata.plot.scatter(x = 'Weight', y = "Price", color = "blue", ax = subplot[1,2])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
gd = carpricesdata.groupby(['FuelType'])

# %%
gd.size()
# Out:
# FuelType
# CNG         17
# Diesel     154
# Petrol    1260
# dtype: int64

# %%
gd.size().plot(kind = 'bar', title = "bar graph between fueltype", color = ['blue','red','yellow'])
# Out:
# <Axes: title={'center': 'bar graph between fueltype'}, xlabel='FuelType'>

# %%
carpricesdata.boxplot(column = 'Price', by = 'FuelType', figsize= (10,5), vert = True)
# Out:
# <Axes: title={'center': 'Price'}, xlabel='FuelType'>

# %%
crosstabresult = pd.crosstab(index = carpricesdata['FuelType'], columns= carpricesdata['MetColor'])

# %%
crosstabresult
# Out:
# MetColor    0    1
# FuelType
# CNG         4   13
# Diesel     53  101
# Petrol    409  851

# %%
crosstabresult.plot.bar(figsize = (10,5), color = ['blue','red'])
# Out:
# <Axes: xlabel='FuelType'>

# %%
def PlotBarCharts(inpdata, colstoplot):
    # %matplotlib inline
    import matplotlib.pyplot as plt
    fig, subplots = plt.subplots(nrows= 1, ncols= len(colstoplot), figsize=(20,5))
    fig.suptitle('Bar chart of: ' + str(colstoplot))
    
    for colname, plotnumber in zip(colstoplot, range(len(colstoplot))):
        inpdata.groupby(colname).size().plot(kind='bar', ax =subplots[plotnumber])

# %%
PlotBarCharts(carpricesdata, colstoplot = ['FuelType','HP','MetColor','Automatic','CC','Doors'])

# %%
carpricesdata.hist(['Price','Weight','KM','Age'],figsize = (18,10))
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Weight'}>],
#        [<Axes: title={'center': 'KM'}>, <Axes: title={'center': 'Age'}>]],
#       dtype=object)

# %% [markdown]
# ## Step 7- Outlier Treatment

# %%
carpricesdata['Weight'].mean()
# Out:
# 1072.314724354501

# %%
len(carpricesdata['Weight'][carpricesdata['Weight'] >1400])
# Out:
# 5

# %%
carpricesdata['Weight'][carpricesdata['Weight'] < 1400].sort_values(ascending = False)
# Out:
# 112     1320.0
# 138     1320.0
# 115     1280.0
# 119     1275.0
# 68      1275.0
#          ...
# 927     1000.0
# 1410    1000.0
# 605     1000.0
# 1021    1000.0
# 957     1000.0
# Name: Weight, Length: 1428, dtype: float64

# %%
carpricesdata['Weight'][carpricesdata['Weight'] > 1400] = 1320

# %%
carpricesdata['Weight'].sort_values(ascending = False)
# Out:
# 110     1320.0
# 138     1320.0
# 960     1320.0
# 109     1320.0
# 221     1320.0
#          ...
# 1000    1000.0
# 957     1000.0
# 605     1000.0
# 1396       NaN
# 1408       NaN
# Name: Weight, Length: 1435, dtype: float64

# %%
len(carpricesdata['Price'][carpricesdata['Price'] >29000])
# Out:
# 3

# %%
carpricesdata['Price'][carpricesdata['Price'] < 25000].sort_values(ascending = False)
# Out:
# 115     24990
# 112     24950
# 147     24500
# 141     23950
# 171     23750
#         ...
# 402      5150
# 192      4750
# 393      4450
# 1048     4400
# 191      4350
# Name: Price, Length: 1432, dtype: int64

# %%
carpricesdata['Price'][carpricesdata['Price'] >29000] = 24990

# %%
carpricesdata['Price'].sort_values(ascending = False)
# Out:
# 109     24990
# 110     24990
# 111     24990
# 115     24990
# 112     24950
#         ...
# 402      5150
# 192      4750
# 393      4450
# 1048     4400
# 191      4350
# Name: Price, Length: 1435, dtype: int64

# %%
carpricesdata.hist(['Price','Weight'],figsize=(10,3))
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Weight'}>]], dtype=object)

# %% [markdown]
# ## Step 8- Missing Value Treatment

# %%
carpricesdata.groupby('FuelType')['CC'].mean()
# Out:
# FuelType
# CNG       1599.882353
# Diesel    1976.396104
# Petrol    1516.058824
# Name: CC, dtype: float64

# %%
carpricesdata.isnull()
# Out:
#       Price    Age     KM  FuelType     HP  MetColor  Automatic     CC  Doors  \
# 0     False  False  False     False  False     False      False  False  False
# 1     False  False  False     False  False     False      False  False  False
# 2     False  False  False     False  False     False      False  False  False
# 3     False  False  False     False  False     False      False  False  False
# 4     False  False  False     False  False     False      False  False  False
# ...     ...    ...    ...       ...    ...       ...        ...    ...    ...
# 1431  False  False  False     False  False     False      False  False  False
# 1432  False  False  False     False  False     False      False  False  False
# 1433  False  False  False     False  False     False      False  False  False
# 1434  False  False  False     False  False     False      False  False  False
# 1435  False  False  False     False  False     False      False  False  False
#
#       Weight
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 1431   False
# 1432   False
# 1433   False
# 1434   False
# 1435   False
#
# [1435 rows x 10 columns]

# %%
carpricesdata.isnull().sum()
# Out:
# Price        0
# Age          2
# KM           0
# FuelType     4
# HP           0
# MetColor     0
# Automatic    0
# CC           2
# Doors        0
# Weight       2
# dtype: int64

# %%
carpricesdata.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
carpricesdata['FuelType'].mode()
# Out:
# 0    Petrol
# Name: FuelType, dtype: object

# %%
carpricesdata['FuelType'].mode()[0]
# Out:
# 'Petrol'

# %%
carpricesdata['CC'].mode()[0]
# Out:
# 1600.0

# %%
carpricesdata['Age'].median()
# Out:
# 61.0

# %%
carpricesdata['Weight'].median()
# Out:
# 1070.0

# %%
carpricesdata['FuelType'].fillna(value = carpricesdata['FuelType'].mode()[0],inplace =True)
carpricesdata['CC'].fillna(value =carpricesdata['CC'].mode()[0],inplace =True)


carpricesdata['Age'].fillna(value =carpricesdata['Age'].median(),inplace =True)
carpricesdata['Weight'].fillna(value =carpricesdata['Weight'].median(),inplace =True)

# %%
carpricesdata.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %% [markdown]
# ## Step 9 - Feature Selection (Visual)

# %%
continuouscols = ['Age','Weight','KM']

for cols in continuouscols:
    carpricesdata.plot.scatter(x =cols, y='Price', title = cols + ' vs ' + 'Price')

# %%
corrcols = ['Price',"Age",'KM',"Weight"]

corrdata = carpricesdata[corrcols].corr()
corrdata
# Out:
#            Price       Age        KM    Weight
# Price   1.000000 -0.880043 -0.573402  0.580007
# Age    -0.880043  1.000000  0.502604 -0.488324
# KM     -0.573402  0.502604  1.000000 -0.013607
# Weight  0.580007 -0.488324 -0.013607  1.000000

# %%
corrdata['Price'][abs(corrdata['Price']) > 0.5]
# Out:
# Price     1.000000
# Age      -0.880043
# KM       -0.573402
# Weight    0.580007
# Name: Price, dtype: float64

# %% [markdown]
# Final Selected Cols : "Age","KM","Weight"

# %%
catecols = ['FuelType','HP','MetColor','Automatic','CC','Doors']

import matplotlib.pyplot as plt
fig, subplot = plt.subplots(nrows = 1, ncols = len(catecols),figsize = (50,10))
fig.suptitle(f"Price vs {catecols}" )

for cols, col_len in zip(catecols,range(len(catecols))):
    carpricesdata.boxplot(column = 'Price', by = cols, figsize= (5,5), vert = True, ax = subplot[col_len])

# %%
categorygrouplist = carpricesdata.groupby('FuelType')['Price'].apply(list)
categorygrouplist
# Out:
# FuelType
# CNG       [7750, 11950, 11950, 14950, 12950, 8500, 9250,...
# Diesel    [13500, 13750, 13950, 14950, 13750, 12950, 169...
# Petrol    [21500, 20950, 19950, 19600, 21500, 22500, 220...
# Name: Price, dtype: object

# %%
def funcANOVA(inpdata, targetvariable, cate_list):
    from scipy.stats import f_oneway
    
    select_cate = []
    
    for pred in cate_list:
        categorygrouplist = inpdata.groupby(pred)[targetvariable].apply(list)
        ANOVA_result = f_oneway(*categorygrouplist)
        
        if (ANOVA_result[1] < 0.05):
            print(pred, 'is correlated with', targetvariable,'| P-Value:',ANOVA_result[1])
            select_cate.append(pred)
        else:
            print(pred, 'is not correlated with', targetvariable,'| P-Value:',ANOVA_result[1])
        
    return select_cate

# %%
cate_list = ['FuelType','HP','MetColor','Automatic','CC','Doors']
funcANOVA(carpricesdata,'Price',cate_list )
# Out:
# FuelType is not correlated with Price | P-Value: 0.13509668858708382
# HP is correlated with Price | P-Value: 1.9274014078136855e-103
# MetColor is correlated with Price | P-Value: 2.9082820205816128e-05
# Automatic is not correlated with Price | P-Value: 0.17860614078485976
# CC is correlated with Price | P-Value: 4.667580175740994e-49
# Doors is correlated with Price | P-Value: 1.0200265373934503e-12
# ['HP', 'MetColor', 'CC', 'Doors']

# %%
selectedcols = ["Age",'KM',"Weight",'HP', 'MetColor', 'CC', 'Doors']
DataForML = carpricesdata[selectedcols]
DataForML
# Out:
#        Age     KM  Weight   HP  MetColor      CC  Doors
# 0     23.0  46986  1165.0   90         1  2000.0      3
# 1     23.0  72937  1165.0   90         1  2000.0      3
# 2     24.0  41711  1165.0   90         1  2000.0      3
# 3     26.0  48000  1165.0   90         0  2000.0      3
# 4     30.0  38500  1170.0   90         0  2000.0      3
# ...    ...    ...     ...  ...       ...     ...    ...
# 1431  69.0  20544  1025.0   86         1  1300.0      3
# 1432  72.0  19000  1015.0   86         0  1300.0      3
# 1433  71.0  17016  1015.0   86         0  1300.0      3
# 1434  70.0  16916  1015.0   86         1  1300.0      3
# 1435  76.0      1  1114.0  110         0  1600.0      5
#
# [1435 rows x 7 columns]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Project Machine Learning\\Car Price Data Analysis'

# %%
DataForML.to_pickle('DataForML.pkl')

# %%
import pandas as pd
DataForML = pd.read_pickle('DataForML.pkl')

# %%
DataForML.head()
# Out:
#     Age     KM  Weight  HP  MetColor      CC  Doors
# 0  23.0  46986  1165.0  90         1  2000.0      3
# 1  23.0  72937  1165.0  90         1  2000.0      3
# 2  24.0  41711  1165.0  90         1  2000.0      3
# 3  26.0  48000  1165.0  90         0  2000.0      3
# 4  30.0  38500  1170.0  90         0  2000.0      3

# %% [markdown]
# ## Step 10 - Data pre-processing for ML

# %%
DataForML_Numeric = pd.get_dummies(DataForML)

# %%
DataForML_Numeric['Price'] = carpricesdata['Price']

# %%
DataForML_Numeric.head(10)
# Out:
#     Age     KM  Weight   HP  MetColor      CC  Doors  Price
# 0  23.0  46986  1165.0   90         1  2000.0      3  13500
# 1  23.0  72937  1165.0   90         1  2000.0      3  13750
# 2  24.0  41711  1165.0   90         1  2000.0      3  13950
# 3  26.0  48000  1165.0   90         0  2000.0      3  14950
# 4  30.0  38500  1170.0   90         0  2000.0      3  13750
# 5  32.0  61000  1170.0   90         0  2000.0      3  12950
# 6  27.0  94612  1245.0   90         1  2000.0      3  16900
# 7  30.0  75889  1245.0   90         1  2000.0      3  18600
# 8  27.0  19700  1185.0  192         0  1800.0      3  21500
# 9  23.0  71138  1105.0   69         0  1900.0      3  12950

# %% [markdown]
# ## Step 11 - Splitting Data into Training and Testing

# %%
DataForML_Numeric.columns
# Out:
# Index(['Age', 'KM', 'Weight', 'HP', 'MetColor', 'CC', 'Doors', 'Price'], dtype='object')

# %%
TargetVar = 'Price'
Pred = ['Age', 'KM', 'Weight', 'HP', 'MetColor', 'CC', 'Doors']

X = DataForML_Numeric[Pred].values
y = DataForML_Numeric[TargetVar].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 41)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1004, 7)
# (431, 7)
# (1004,)
# (431,)

# %%
# np.set_printoptions(suppress = True)
X_train[0:10]
# Out:
# array([[   60., 61100.,  1015.,    86.,     1.,  1300.,     3.],
#        [   74., 61700.,  1070.,   110.,     0.,  1600.,     5.],
#        [   28., 30993.,  1130.,   110.,     1.,  1600.,     5.],
#        [   70., 89983.,  1055.,   110.,     0.,  1600.,     3.],
#        [   54., 39291.,  1040.,   110.,     1.,  1600.,     3.],
#        [   65., 68000.,  1015.,    86.,     1.,  1300.,     3.],
#        [   13., 19988.,  1130.,   110.,     1.,  1600.,     5.],
#        [   39., 43254.,  1075.,   110.,     1.,  1600.,     5.],
#        [   65., 66000.,  1015.,    86.,     1.,  1300.,     3.],
#        [   68., 66785.,  1045.,    86.,     0.,  1300.,     3.]])

# %%
y_train[0:10]
# Out:
# array([ 7950,  8950, 18950,  8450, 10950,  8950, 24500, 13875,  7800,
#        10400], dtype=int64)

# %% [markdown]
# ## Step - 12 Trying Different Algorithm

# %% [markdown]
# ### 1. Multiple Linear Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

print(RegModel)

LREG = RegModel.fit(X_train, y_train)

from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))



print('\n ####Model Validation and Accuracy Calculations####')

prediction = LREG.predict(X_test)
TestingDataResults  = pd.DataFrame(data = X_test, columns = Pred)
TestingDataResults[TargetVar]= y_test
TestingDataResults['Predicted '+ TargetVar] = np.round(prediction)
print(TestingDataResults.head(10))

TestingDataResults['APE'] = 100*(abs(
    TestingDataResults['Price']-TestingDataResults['Predicted Price'])/TestingDataResults['Price'])

print(TestingDataResults[['Price','Predicted Price','APE']].head())

MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

Accuracy = 100 - MAPE
MedianAccuracy = 100 - MedianMAPE

print('Mean Accuracy on test data',Accuracy,'%')
print('Median Accuracy on test data',MedianAccuracy,'%')


def Accuracy_score(orig,pred):
    MAPE =np.mean(100* abs(orig-pred)/orig)
    return (100-MAPE)

from sklearn.metrics import make_scorer
custom_scoring  = make_scorer(Accuracy_score, greater_is_better= True)

from sklearn.model_selection import cross_val_score
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scoring)

print('\n Accuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\n Final Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# LinearRegression()
# R2 Value: 0.8860710167393759
#
#  ####Model Validation and Accuracy Calculations####
#     Age       KM  Weight     HP  MetColor      CC  Doors  Price  \
# 0  71.0  83291.0  1070.0  110.0       1.0  1600.0    5.0   7500
# 1  75.0  74096.0  1050.0  110.0       1.0  1600.0    3.0   7400
# 2  56.0  19313.0  1025.0   97.0       0.0  1400.0    3.0  10500
# 3  78.0  97534.0  1070.0  110.0       1.0  1600.0    5.0   8900
# 4  42.0  42560.0  1080.0  110.0       1.0  1600.0    5.0  13950
# 5  37.0  44757.0  1025.0   97.0       0.0  1400.0    3.0   9950
# 6  12.0  13634.0  1115.0  110.0       1.0  1600.0    5.0  19500
# 7  78.0  72090.0  1070.0  110.0       1.0  1600.0    5.0   7750
# 8  48.0  56675.0  1025.0   97.0       1.0  1400.0    3.0   9475
# 9  39.0  25062.0  1080.0  110.0       1.0  1600.0    5.0  13750
#
#    Predicted Price
# 0           8752.0
# 1           8139.0
# 2          10645.0
# 3           7683.0
# 4          13156.0
# 5          12465.0
# 6          18189.0
# 7           8112.0
# 8          10979.0
# 9          13806.0
#    Price  Predicted Price        APE
# 0   7500           8752.0  16.693333
# 1   7400           8139.0   9.986486
# 2  10500          10645.0   1.380952
# 3   8900           7683.0  13.674157
# 4  13950          13156.0   5.691756
# Mean Accuracy on test data 89.62787964975202 %
# Median Accuracy on test data 92.53086419753086 %
#
#  Accuracy values for 10-fold Cross Validation:
#  [90.44409532 89.56365325 88.73647401 92.02171842 89.47108843 91.81973698
#  91.20551266 87.79318959 90.62790478 88.577706  ]
#
#  Final Average Accuracy of the model: 90.03

# %%
TestingDataResults['PriceAVG']= TestingDataResults['Price'].mean()

# %%
TestingDataResults.head(5)
# Out:
#     Age       KM  Weight     HP  MetColor  ...  Doors  Price  Predicted Price  \
# 0  71.0  83291.0  1070.0  110.0       1.0  ...    5.0   7500           8752.0
# 1  75.0  74096.0  1050.0  110.0       1.0  ...    3.0   7400           8139.0
# 2  56.0  19313.0  1025.0   97.0       0.0  ...    3.0  10500          10645.0
# 3  78.0  97534.0  1070.0  110.0       1.0  ...    5.0   8900           7683.0
# 4  42.0  42560.0  1080.0  110.0       1.0  ...    5.0  13950          13156.0
#
#          APE      PriceAVG
# 0  16.693333  10270.366589
# 1   9.986486  10270.366589
# 2   1.380952  10270.366589
# 3  13.674157  10270.366589
# 4   5.691756  10270.366589
#
# [5 rows x 11 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# TestingDataResults.plot.scatter(x= 'Age',y='Price',color = 'blue')
# TestingDataResults.plot.scatter(x= 'Age',y='Predicted Price',color = 'red')
# TestingDataResults.plot.scatter(x= 'Age',y='PriceAVG',color = 'green')

plt.scatter(x=TestingDataResults['Age'],y = TestingDataResults['Price'],color = 'blue')
plt.scatter(x=TestingDataResults['Age'],y = TestingDataResults['Predicted Price'],color = 'red')
plt.scatter(x=TestingDataResults['Age'],y = TestingDataResults['PriceAVG'],color = 'green')

# %%
LREG.coef_
# Out:
# array([-118.38182869,   -0.01686781,   28.38242364,   33.9929008 ,
#          17.64738313,   -2.50675547, -136.77969812])

# %%
LREG.intercept_
# Out:
# -10869.482717520556

# %% [markdown]
# ## 2. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
RegModel = DecisionTreeRegressor(max_depth= 3, criterion= 'squared_error')

print(RegModel)

DT = RegModel.fit(X_train, y_train)

from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train, DT.predict(X_train)))


# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(DT.feature_importances_, index=Pred)
feature_importances.nlargest(10).plot(kind='barh')
print('\n ####Model Validation and Accuracy Calculations####')

prediction = DT.predict(X_test)
TestingDataResults  = pd.DataFrame(data = X_test, columns = Pred)
TestingDataResults[TargetVar]= y_test
TestingDataResults['Predicted '+ TargetVar] = np.round(prediction)
print(TestingDataResults.head(10))

TestingDataResults['APE'] = 100*(abs(
    TestingDataResults['Price']-TestingDataResults['Predicted Price'])/TestingDataResults['Price'])

print(TestingDataResults[['Price','Predicted Price','APE']].head())

MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

Accuracy = 100 - MAPE
MedianAccuracy = 100 - MedianMAPE

print('Mean Accuracy on test data',Accuracy,'%')
print('Median Accuracy on test data',MedianAccuracy,'%')


def Accuracy_score(orig,pred):
    MAPE =np.mean(100* abs(orig-pred)/orig)
    return (100-MAPE)

from sklearn.metrics import make_scorer
custom_scoring  = make_scorer(Accuracy_score, greater_is_better= True)

from sklearn.model_selection import cross_val_score
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scoring)

print('\n Accuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\n Final Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# DecisionTreeRegressor(max_depth=3)
# R2 Value: 0.86711882754065
#
#  ####Model Validation and Accuracy Calculations####
#     Age       KM  Weight     HP  MetColor      CC  Doors  Price  \
# 0  71.0  83291.0  1070.0  110.0       1.0  1600.0    5.0   7500
# 1  75.0  74096.0  1050.0  110.0       1.0  1600.0    3.0   7400
# 2  56.0  19313.0  1025.0   97.0       0.0  1400.0    3.0  10500
# 3  78.0  97534.0  1070.0  110.0       1.0  1600.0    5.0   8900
# 4  42.0  42560.0  1080.0  110.0       1.0  1600.0    5.0  13950
# 5  37.0  44757.0  1025.0   97.0       0.0  1400.0    3.0   9950
# 6  12.0  13634.0  1115.0  110.0       1.0  1600.0    5.0  19500
# 7  78.0  72090.0  1070.0  110.0       1.0  1600.0    5.0   7750
# 8  48.0  56675.0  1025.0   97.0       1.0  1400.0    3.0   9475
# 9  39.0  25062.0  1080.0  110.0       1.0  1600.0    5.0  13750
#
#    Predicted Price
# 0           7911.0
# 1           7911.0
# 2           9436.0
# 3           7911.0
# 4          12383.0
# 5          12383.0
# 6          18298.0
# 7           7911.0
# 8          10795.0
# 9          12383.0
#    Price  Predicted Price        APE
# 0   7500           7911.0   5.480000
# 1   7400           7911.0   6.905405
# 2  10500           9436.0  10.133333
# 3   8900           7911.0  11.112360
# 4  13950          12383.0  11.232975
# Mean Accuracy on test data 89.5851813712103 %
# Median Accuracy on test data 93.07058823529411 %
#
#  Accuracy values for 10-fold Cross Validation:
#  [83.83497421 87.54092648 86.11810534 86.07782878 86.58615835 90.54523664
#  91.78645028 85.63224193 91.26690628 89.39986216]
#
#  Final Average Accuracy of the model: 87.88

# %%
from IPython.display import Image
from sklearn import tree
import pydotplus

dot_data = tree.export_graphviz(RegModel, out_file = None, feature_names= Pred, class_names= list(TargetVar))

print(dot_data)

graph = pydotplus.graph_from_dot_data(dot_data)

Image(graph.create_png(), width = 1200, height = 900)
# Out:
# digraph Tree {
# node [shape=box, fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="Age <= 32.5\nsquared_error = 13540972.542\nsamples = 1004\nvalue = 10894.603"] ;
# 1 [label="Weight <= 1122.5\nsquared_error = 7666705.619\nsamples = 142\nvalue = 18349.148"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="Age <= 18.0\nsquared_error = 2855594.668\nsamples = 74\nvalue = 16851.622"] ;
# 1 -> 2 ;
# 3 [label="squared_error = 1587419.675\nsamples = 26\nvalue = 18297.692"] ;
# 2 -> 3 ;
# 4 [label="squared_error = 1796292.014\nsamples = 48\nvalue = 16068.333"] ;
# 2 -> 4 ;
# 5 [label="KM <= 36006.0\nsquared_error = 7806071.537\nsamples = 68\nvalue = 19978.809"] ;
# 1 -> 5 ;
# 6 [label="squared_error = 4241603.855\nsamples = 42\nvalue = 21160.952"] ;
# 5 -> 6 ;
# 7 [label="squared_error = 7659981.694\nsamples = 26\nvalue = 18069.192"] ;
# 5 -> 7 ;
# 8 [label="Age <= 55.5\nsquared_error = 3846385.135\nsamples = 862\nvalue = 9666.592"] ;
# 0 -> 8 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 9 [label="Age <= 44.5\nsquared_error = 2304719.082\nsamples = 279\nvalue = 11575.086"] ;
# 8 -> 9 ;
# 10 [label="squared_error = 1537680.931\nsamples = 137\nvalue = 12383.431"] ;
# 9 -> 10 ;
# 11 [label="squared_error = 1806119.965\nsamples = 142\nvalue = 10795.204"] ;
# 9 -> 11 ;
# 12 [label="Age <= 68.5\nsquared_error = 2006916.067\nsamples = 583\nvalue = 8753.264"] ;
# 8 -> 12 ;
# 13 [label="squared_error = 1719624.038\nsamples = 322\nvalue = 9436.165"] ;
# 12 -> 13 ;
# 14 [label="squared_error = 1076190.007\nsamples = 261\nvalue = 7910.759"] ;
# 12 -> 14 ;
# }

# %% [markdown]
# ## 3. Random Forest

# %%
TestingDataResults.columns
# Out:
# Index(['Age', 'KM', 'Weight', 'HP', 'MetColor', 'CC', 'Doors', 'Price',
#        'Predicted Price', 'APE'],
#       dtype='object')

# %%
#Random Forest (Bagging of multiple Decision Trees) 
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
RegModel = RandomForestRegressor(max_depth=2, n_estimators=100, criterion='squared_error')

RF = RegModel.fit(X_train, y_train)

from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train, RF.predict(X_train)))


# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(RF.feature_importances_, index=Pred)
feature_importances.nlargest(10).plot(kind='barh')
print('\n ####Model Validation and Accuracy Calculations####')

prediction = RF.predict(X_test)
TestingDataResults  = pd.DataFrame(data = X_test, columns = Pred)
TestingDataResults[TargetVar]= y_test
TestingDataResults['Predicted '+ TargetVar] = np.round(prediction)
print(TestingDataResults.head(10))

TestingDataResults['APE'] = 100*(abs(
    TestingDataResults['Price']-TestingDataResults['Predicted Price'])/TestingDataResults['Price'])

print(TestingDataResults[['Price','Predicted Price','APE']].head())

MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

Accuracy = 100 - MAPE
MedianAccuracy = 100 - MedianMAPE

print('Mean Accuracy on test data',Accuracy,'%')
print('Median Accuracy on test data',MedianAccuracy,'%')


def Accuracy_score(orig,pred):
    MAPE =np.mean(100* abs(orig-pred)/orig)
    return (100-MAPE)

from sklearn.metrics import make_scorer
custom_scoring  = make_scorer(Accuracy_score, greater_is_better= True)

from sklearn.model_selection import cross_val_score
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scoring)

print('\n Accuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\n Final Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# R2 Value: 0.8299305334299212
#
#  ####Model Validation and Accuracy Calculations####
#     Age       KM  Weight     HP  MetColor      CC  Doors  Price  \
# 0  71.0  83291.0  1070.0  110.0       1.0  1600.0    5.0   7500
# 1  75.0  74096.0  1050.0  110.0       1.0  1600.0    3.0   7400
# 2  56.0  19313.0  1025.0   97.0       0.0  1400.0    3.0  10500
# 3  78.0  97534.0  1070.0  110.0       1.0  1600.0    5.0   8900
# 4  42.0  42560.0  1080.0  110.0       1.0  1600.0    5.0  13950
# 5  37.0  44757.0  1025.0   97.0       0.0  1400.0    3.0   9950
# 6  12.0  13634.0  1115.0  110.0       1.0  1600.0    5.0  19500
# 7  78.0  72090.0  1070.0  110.0       1.0  1600.0    5.0   7750
# 8  48.0  56675.0  1025.0   97.0       1.0  1400.0    3.0   9475
# 9  39.0  25062.0  1080.0  110.0       1.0  1600.0    5.0  13750
#
#    Predicted Price
# 0           8743.0
# 1           8743.0
# 2           9865.0
# 3           8743.0
# 4          11610.0
# 5          11610.0
# 6          17587.0
# 7           8743.0
# 8          11610.0
# 9          11610.0
#    Price  Predicted Price        APE
# 0   7500           8743.0  16.573333
# 1   7400           8743.0  18.148649
# 2  10500           9865.0   6.047619
# 3   8900           8743.0   1.764045
# 4  13950          11610.0  16.774194
# Mean Accuracy on test data 87.86641939793087 %
# Median Accuracy on test data 90.02857142857142 %
#
#  Accuracy values for 10-fold Cross Validation:
#  [78.80877484 85.99742751 84.29562299 85.68217473 88.66261836 88.88601557
#  89.05867071 79.35529118 86.59344733 88.48773168]
#
#  Final Average Accuracy of the model: 85.58

# %% [markdown]
# ### Plotting one of the Decision Trees in Random Forest

# %%
from IPython.display import Image
from sklearn import tree
import pydotplus

dot_data = tree.export_graphviz(RegModel.estimators_[2], out_file = None, feature_names= Pred, class_names= list(TargetVar))

print(dot_data)

graph = pydotplus.graph_from_dot_data(dot_data)

Image(graph.create_png(), width = 1200, height = 900)
# Out:
# digraph Tree {
# node [shape=box, fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="Age <= 31.5\nsquared_error = 13756866.018\nsamples = 625\nvalue = 11008.919"] ;
# 1 [label="HP <= 113.0\nsquared_error = 6723272.854\nsamples = 96\nvalue = 18128.196"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="squared_error = 4439219.373\nsamples = 87\nvalue = 17616.399"] ;
# 1 -> 2 ;
# 3 [label="squared_error = 2194806.222\nsamples = 9\nvalue = 23007.333"] ;
# 1 -> 3 ;
# 4 [label="Age <= 54.5\nsquared_error = 3836793.892\nsamples = 529\nvalue = 9679.314"] ;
# 0 -> 4 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 5 [label="squared_error = 1968655.457\nsamples = 159\nvalue = 11764.217"] ;
# 4 -> 5 ;
# 6 [label="squared_error = 2118046.908\nsamples = 370\nvalue = 8834.271"] ;
# 4 -> 6 ;
# }

# %% [markdown]
# ## 4. AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor (max_depth=2)
RegModel = AdaBoostRegressor (n_estimators=300, base_estimator=DTR, learning_rate=0.01)

AD = RegModel.fit(X_train, y_train)
print(AD)
from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train, AD.predict(X_train)))


# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(AD.feature_importances_, index=Pred)
feature_importances.nlargest(10).plot(kind='barh')
print('\n ####Model Validation and Accuracy Calculations####')

prediction = AD.predict(X_test)
TestingDataResults  = pd.DataFrame(data = X_test, columns = Pred)
TestingDataResults[TargetVar]= y_test
TestingDataResults['Predicted '+ TargetVar] = np.round(prediction)
print(TestingDataResults.head(10))

TestingDataResults['APE'] = 100*(abs(
    TestingDataResults['Price']-TestingDataResults['Predicted Price'])/TestingDataResults['Price'])

print(TestingDataResults[['Price','Predicted Price','APE']].head())

MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

Accuracy = 100 - MAPE
MedianAccuracy = 100 - MedianMAPE

print('Mean Accuracy on test data',Accuracy,'%')
print('Median Accuracy on test data',MedianAccuracy,'%')


def Accuracy_score(orig,pred):
    MAPE =np.mean(100* abs(orig-pred)/orig)
    return (100-MAPE)

from sklearn.metrics import make_scorer
custom_scoring  = make_scorer(Accuracy_score, greater_is_better= True)

from sklearn.model_selection import cross_val_score
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scoring)

print('\n Accuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\n Final Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=2),
#                   learning_rate=0.01, n_estimators=300)
# R2 Value: 0.8401605774285461
#
#  ####Model Validation and Accuracy Calculations####
#     Age       KM  Weight     HP  MetColor      CC  Doors  Price  \
# 0  71.0  83291.0  1070.0  110.0       1.0  1600.0    5.0   7500
# 1  75.0  74096.0  1050.0  110.0       1.0  1600.0    3.0   7400
# 2  56.0  19313.0  1025.0   97.0       0.0  1400.0    3.0  10500
# 3  78.0  97534.0  1070.0  110.0       1.0  1600.0    5.0   8900
# 4  42.0  42560.0  1080.0  110.0       1.0  1600.0    5.0  13950
# 5  37.0  44757.0  1025.0   97.0       0.0  1400.0    3.0   9950
# 6  12.0  13634.0  1115.0  110.0       1.0  1600.0    5.0  19500
# 7  78.0  72090.0  1070.0  110.0       1.0  1600.0    5.0   7750
# 8  48.0  56675.0  1025.0   97.0       1.0  1400.0    3.0   9475
# 9  39.0  25062.0  1080.0  110.0       1.0  1600.0    5.0  13750
#
#    Predicted Price
# 0           8709.0
# 1           8709.0
# 2           9123.0
# 3           8709.0
# 4          11558.0
# 5          11558.0
# 6          17744.0
# 7           8709.0
# 8          11511.0
# 9          11558.0
#    Price  Predicted Price        APE
# 0   7500           8709.0  16.120000
# 1   7400           8709.0  17.689189
# 2  10500           9123.0  13.114286
# 3   8900           8709.0   2.146067
# 4  13950          11558.0  17.146953
# Mean Accuracy on test data 88.11314189382594 %
# Median Accuracy on test data 90.4952380952381 %
#
#  Accuracy values for 10-fold Cross Validation:
#  [78.96550022 86.27866436 84.47386875 85.07275079 89.2806529  89.10681591
#  89.86565889 79.10831477 86.28645437 88.08955462]
#
#  Final Average Accuracy of the model: 85.65

# %% [markdown]
# ### Plotting one of the Decision trees from Adaboost

# %%
from IPython.display import Image
from sklearn import tree
import pydotplus

dot_data = tree.export_graphviz(RegModel.estimators_[2], out_file = None, feature_names= Pred, class_names= list(TargetVar))

print(dot_data)

graph = pydotplus.graph_from_dot_data(dot_data)

Image(graph.create_png(), width = 1200, height = 900)
# Out:
# digraph Tree {
# node [shape=box, fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="Age <= 32.5\nsquared_error = 14077675.082\nsamples = 1004\nvalue = 10926.691"] ;
# 1 [label="HP <= 113.0\nsquared_error = 7110530.076\nsamples = 145\nvalue = 18458.31"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="squared_error = 5186649.84\nsamples = 125\nvalue = 17836.6"] ;
# 1 -> 2 ;
# 3 [label="squared_error = 1620424.0\nsamples = 20\nvalue = 22344.0"] ;
# 1 -> 3 ;
# 4 [label="Age <= 54.5\nsquared_error = 4062138.092\nsamples = 859\nvalue = 9655.347"] ;
# 0 -> 4 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 5 [label="squared_error = 2528709.605\nsamples = 248\nvalue = 11834.492"] ;
# 4 -> 5 ;
# 6 [label="squared_error = 1974760.314\nsamples = 611\nvalue = 8770.849"] ;
# 4 -> 6 ;
# }

# %% [markdown]
# ## 5. XGBoost

# %%
import xgboost
from xgboost import XGBRegressor 
from sklearn.model_selection import train_test_split
RegModel = XGBRegressor(max_depth=5,
                        learning_rate=0.1,
                        n_estimators=300,
                        objective='reg:squarederror',
                        booster='gbtree',
                        )
XGB = RegModel.fit(X_train, y_train)
print(XGB)
from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train, XGB.predict(X_train)))


# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(XGB.feature_importances_, index=Pred)
feature_importances.nlargest(10).plot(kind='barh')
print('\n ####Model Validation and Accuracy Calculations####')

prediction = XGB.predict(X_test)
TestingDataResults  = pd.DataFrame(data = X_test, columns = Pred)
TestingDataResults[TargetVar]= y_test
TestingDataResults['Predicted '+ TargetVar] = np.round(prediction)
print(TestingDataResults.head(10))

TestingDataResults['APE'] = 100*(abs(
    TestingDataResults['Price']-TestingDataResults['Predicted Price'])/TestingDataResults['Price'])

print(TestingDataResults[['Price','Predicted Price','APE']].head())

MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

Accuracy = 100 - MAPE
MedianAccuracy = 100 - MedianMAPE

print('Mean Accuracy on test data',Accuracy,'%')
print('Median Accuracy on test data',MedianAccuracy,'%')


def Accuracy_score(orig,pred):
    MAPE =np.mean(100* abs(orig-pred)/orig)
    return (100-MAPE)

from sklearn.metrics import make_scorer
custom_scoring  = make_scorer(Accuracy_score, greater_is_better= True)

from sklearn.model_selection import cross_val_score
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scoring)

print('\n Accuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\n Final Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
# R2 Value: 0.9905732643295581
#
#  ####Model Validation and Accuracy Calculations####
#     Age       KM  Weight     HP  MetColor      CC  Doors  Price  \
# 0  71.0  83291.0  1070.0  110.0       1.0  1600.0    5.0   7500
# 1  75.0  74096.0  1050.0  110.0       1.0  1600.0    3.0   7400
# 2  56.0  19313.0  1025.0   97.0       0.0  1400.0    3.0  10500
# 3  78.0  97534.0  1070.0  110.0       1.0  1600.0    5.0   8900
# 4  42.0  42560.0  1080.0  110.0       1.0  1600.0    5.0  13950
# 5  37.0  44757.0  1025.0   97.0       0.0  1400.0    3.0   9950
# 6  12.0  13634.0  1115.0  110.0       1.0  1600.0    5.0  19500
# 7  78.0  72090.0  1070.0  110.0       1.0  1600.0    5.0   7750
# 8  48.0  56675.0  1025.0   97.0       1.0  1400.0    3.0   9475
# 9  39.0  25062.0  1080.0  110.0       1.0  1600.0    5.0  13750
#
#    Predicted Price
# 0           7367.0
# 1           7671.0
# 2          10784.0
# 3           7597.0
# 4          13336.0
# 5          11507.0
# 6          19406.0
# 7           7858.0
# 8          10102.0
# 9          13268.0
#    Price  Predicted Price        APE
# 0   7500           7367.0   1.773333
# 1   7400           7671.0   3.662162
# 2  10500          10784.0   2.704762
# 3   8900           7597.0  14.640449
# 4  13950          13336.0   4.401434
# Mean Accuracy on test data 90.94788603727139 %
# Median Accuracy on test data 93.53072625698324 %
#
#  Accuracy values for 10-fold Cross Validation:
#  [88.70657969 90.67761527 89.06962972 90.77305081 89.78153941 92.01548284
#  91.96260505 86.59776876 90.92117002 90.5619605 ]
#
#  Final Average Accuracy of the model: 90.11

# %% [markdown]
# ### Plotting a single Decision tree out of XGBoost

# %%
from xgboost import plot_tree
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(100, 40))
plot_tree (XGB, num_trees=10, ax=ax)
# Double click on the graph to zoom in
# Out:
# <Axes: >

# %% [markdown]
# ## 6. KNN

# %%
from sklearn.neighbors import KNeighborsRegressor 
RegModel = KNeighborsRegressor(n_neighbors=3)

# Printing all the parameters of KNN
print (RegModel)

KNN = RegModel.fit(X_train, y_train)
print(KNN)
from sklearn import metrics
print('R2 Value:',metrics.r2_score(y_train, KNN.predict(X_train)))


prediction = KNN.predict(X_test)
TestingDataResults  = pd.DataFrame(data = X_test, columns = Pred)
TestingDataResults[TargetVar]= y_test
TestingDataResults['Predicted '+ TargetVar] = np.round(prediction)
print(TestingDataResults.head(10))

TestingDataResults['APE'] = 100*(abs(
    TestingDataResults['Price']-TestingDataResults['Predicted Price'])/TestingDataResults['Price'])

print(TestingDataResults[['Price','Predicted Price','APE']].head())

MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

Accuracy = 100 - MAPE
MedianAccuracy = 100 - MedianMAPE

print('Mean Accuracy on test data',Accuracy,'%')
print('Median Accuracy on test data',MedianAccuracy,'%')


def Accuracy_score(orig,pred):
    MAPE =np.mean(100* abs(orig-pred)/orig)
    return (100-MAPE)

from sklearn.metrics import make_scorer
custom_scoring  = make_scorer(Accuracy_score, greater_is_better= True)

from sklearn.model_selection import cross_val_score
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scoring)

print('\n Accuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\n Final Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# KNeighborsRegressor(n_neighbors=3)
# KNeighborsRegressor(n_neighbors=3)
# R2 Value: 0.740912316731376
#     Age       KM  Weight     HP  MetColor      CC  Doors  Price  \
# 0  71.0  83291.0  1070.0  110.0       1.0  1600.0    5.0   7500
# 1  75.0  74096.0  1050.0  110.0       1.0  1600.0    3.0   7400
# 2  56.0  19313.0  1025.0   97.0       0.0  1400.0    3.0  10500
# 3  78.0  97534.0  1070.0  110.0       1.0  1600.0    5.0   8900
# 4  42.0  42560.0  1080.0  110.0       1.0  1600.0    5.0  13950
# 5  37.0  44757.0  1025.0   97.0       0.0  1400.0    3.0   9950
# 6  12.0  13634.0  1115.0  110.0       1.0  1600.0    5.0  19500
# 7  78.0  72090.0  1070.0  110.0       1.0  1600.0    5.0   7750
# 8  48.0  56675.0  1025.0   97.0       1.0  1400.0    3.0   9475
# 9  39.0  25062.0  1080.0  110.0       1.0  1600.0    5.0  13750
#
#    Predicted Price
# 0          10567.0
# 1           8100.0
# 2          17198.0
# 3           9600.0
# 4          10732.0
# 5           9383.0
# 6          19900.0
# 7          10250.0
# 8           9247.0
# 9          13900.0
#    Price  Predicted Price        APE
# 0   7500          10567.0  40.893333
# 1   7400           8100.0   9.459459
# 2  10500          17198.0  63.790476
# 3   8900           9600.0   7.865169
# 4  13950          10732.0  23.068100
# Mean Accuracy on test data 81.86157180023184 %
# Median Accuracy on test data 86.54935622317596 %
#
#  Accuracy values for 10-fold Cross Validation:
#  [68.34232875 79.79359582 82.25228133 85.93695354 84.10573718 84.42870551
#  82.52243359 73.13117629 73.35083758 65.47822435]
#
#  Final Average Accuracy of the model: 77.93

# %% [markdown]
# ## Step 13 - Selection of Best Model

# %% [markdown]
# ## Step 14 - Deployment of Model

# %%
# Separate Target Variable and Predictor Variables
TargetVariable='Price'

# Selecting the final set of predictors for the deployment
# Based on the variable importance charts of multiple algorithms above 
Predictors=['Age', 'KM', 'Weight']

# Selecting final columns
DataForML=carpricesdata[ Predictors] 
DataForML.to_pickle('DataForML.pkl')

X=DataForML_Numeric[Predictors].values
y=DataForML_Numeric [TargetVariable].values

### Sandardization of data ###
from sklearn.preprocessing import StandardScaler, MinMaxScaler 

#Choose either standardization or Normalization
# On this data Min Max Normalization produced better results

#Choose between standardization and MinMAx normalization
#PredictorScaler=StandardScaler() 
PredictorScaler=MinMaxScaler()

# Storing the fit object for later reference 
PredictorScalerFit=PredictorScaler.fit(X)

#Generating the standardized values of X 
X=PredictorScalerFit.transform(X)

print(X.shape)
print(y.shape)
# Out:
# (1435, 3)
# (1435,)

# %%
X[0:4]
# Out:
# array([[0.27848101, 0.19335471, 0.515625  ],
#        [0.27848101, 0.30014938, 0.515625  ],
#        [0.29113924, 0.1716468 , 0.515625  ],
#        [0.3164557 , 0.19752756, 0.515625  ]])

# %%
y[0:4]
# Out:
# array([13500, 13750, 13950, 14950], dtype=int64)

# %%
DataForML.head()
# Out:
#     Age     KM  Weight
# 0  23.0  46986  1165.0
# 1  23.0  72937  1165.0
# 2  24.0  41711  1165.0
# 3  26.0  48000  1165.0
# 4  30.0  38500  1170.0

# %% [markdown]
# ## Step 15 - Cross validating the final model accuracy with less predictors

# %%
# Importing cross validation function from sklearn 

from sklearn.model_selection import cross_val_score


# Using final hyperparameters
# Xtreme Gradient Boosting (XGBoost) 
from xgboost import XGBRegressor 
RegModel=XGBRegressor (max_depth=5,
                  learning_rate=0.1,
                  n_estimators=100,
                  objective='reg:squarederror', 
                  booster='gbtree')

# from sklearn.tree import DecisionTreeRegressor
# RegModel = DecisionTreeRegressor(max_depth=3, criterion='squared_error')

def Accuracy_score(orig,pred):
    MAPE =np.mean(100* abs(orig-pred)/orig)
    return (100-MAPE)

from sklearn.metrics import make_scorer
custom_scoring  = make_scorer(Accuracy_score, greater_is_better= True)
# Running 10-Fold Cross validation on a given algorithm
# Passing full data x and y because the K-fold will split the data and automatically choos 
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scoring) 
print('\nAccuracy values for 10-fold Cross Validation: \n', Accuracy_Values) 
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(), 2))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [88.49843188 91.09833372 89.77122439 91.29017458 90.25100876 92.58272875
#  92.61139904 87.46490813 91.64525632 90.50432465]
#
# Final Average Accuracy of the model: 90.57

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 1. Retraining the model using 100% data

# %%
#Training the model on 100% Data available 
Final_XGB_Model=RegModel.fit(X,y)

# %% [markdown]
# ### Step 2. Save the model as a serialized file which can be stored anywhere

# %%
import pickle 
import os
# Saving the Python objects as serialized files can be done using pickle library #Here let us save the Final model
with open('Final_XGB_Model.pkl', 'wb') as fileWriteStream:
    pickle.dump(Final_XGB_Model, fileWriteStream)
    #Don't forget to close the filestream! 
    fileWriteStream.close()
print('pickle file of Predictive Model is saved at Location: ', os.getcwd())
# Out:
# pickle file of Predictive Model is saved at Location:  C:\Users\Administrator\Project Machine Learning\Car Price Data Analysis

# %% [markdown]
# ### Step 3. Create a python function

# %%
#This Function can be called from any from any front end tool/website
def FunctionPredictResult(InputData):
    import pandas as pd
    
    
    Num_Inputs= InputData.shape[0]
    
    # Making sure the input data has same columns as it was used for training the model
    # Also, if standardization/normalization was done, then same must be done for new input
    
    # Appending the new data with the Training data
    DataForML=pd.read_pickle( 'DataForML.pkl')
    InputData=pd.concat([InputData,DataForML],ignore_index =True)
    
    #Generating dummy variables for rest of the nominal variables
    InputData=pd.get_dummies(InputData)

    # Maintaining the same order of columns as it was during the model training 
    Predictors=['Age', 'KM', 'Weight']

    #Generating the input values to the model 
    X=InputData[Predictors].values[0: Num_Inputs]

    #Generating the standardized values of X since it was done while model training also
    X=PredictorScalerFit.transform(X)
    
    #Loading the Function from pickle file
    import pickle
    with open('Final_XGB_Model.pkl', 'rb') as fileReadStream:
        PredictionModel=pickle.load(fileReadStream)
        # Don't forget to close the filestream!
        fileReadStream.close()
    #GenPrice Predictions
    Prediction=PredictionModel.predict(X)
    PredictionResult=pd.DataFrame (Prediction, columns=['Prediction'])
    return(round (PredictionResult))

# %%
 # Calling the function for some new data
NewSampleData=pd.DataFrame(
data=[[23,46986,1165],
        [10,65054,2454],
        [8,380,1875]],
columns=['Age', 'KM', 'Weight'])

print(NewSampleData)

# Calling the Function for prediction
FunctionPredictResult(InputData= NewSampleData)
# Out:
#    Age     KM  Weight
# 0   23  46986    1165
# 1   10  65054    2454
# 2    8    380    1875
#    Prediction
# 0     14796.0
# 1     21297.0
# 2     24413.0

# %% [markdown]
# ## For Deployment is API

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor

# Define the steps in the pipeline
steps = [
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('scaler', MinMaxScaler()),                   # Scale features to a specified range
    ('xgboost', XGBRegressor())                    # XGBoost model
]

# Create the pipeline
xgboost_pipeline = Pipeline(steps)

# Now you can use this pipeline for training and prediction
# For example, you can fit the model on training data
xgboost_pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', MinMaxScaler()),
#                 ('xgboost',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=None, ...))])
